# %%
import cv2
import glob
import matplotlib.pyplot as plt
from ParkingFunc import Parking
import numpy as np
park = Parking()
path_test_images = f"data\\test_images"
test_images = [plt.imread(path) for path in glob.glob(path_test_images+"\\*.jpg")]
park.img_show(test_images)

# %%
lower = np.uint8([100,100,100])
upper = np.uint8([255,255,255])
    # lower_red和高于upper_red的部分分别变成0，lower_red～upper_red之间的值变成255,相当于过滤背景
new_image = cv2.inRange(test_images[0], lower, upper)
park.cv_show(new_image)
